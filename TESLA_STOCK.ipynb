# %%
# To convert N-D array data into a data frame - collection of 2D
import pandas as pd

# numerical array mathematical operations
import numpy as np

# simple graphs - bar, pie, line plot , histogram
import matplotlib.pyplot as plt

#for distributional graph - heatmap, violinplot, count plot, density plot
import seaborn as sns

# we have online whihc is interactive and offline 
from plotly.offline import iplot, init_notebook_mode

import cufflinks
cufflinks.go_offline(connected=True)
init_notebook_mode(connected=True)

import matplotlib.pyplot as plt
from matplotlib import ticker 

import folium
# Load the dataset using url
import requests
# simple graphs - bar, pie, line plot , histogram
import matplotlib.pyplot as plt
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
# ...

# %%
tesla_df = pd.read_csv('https://raw.githubusercontent.com/mannavapavan/tesla/master/TSLA.csv')

# %%
tesla_df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  2416.000000  2416.000000  2416.000000  2416.000000  2416.000000
# mean    186.271147   189.578224   182.916639   186.403651   186.403651
# std     118.740163   120.892329   116.857591   119.136020   119.136020
# min      16.139999    16.629999    14.980000    15.800000    15.800000
# 25%      34.342498    34.897501    33.587501    34.400002    34.400002
# 50%     213.035003   216.745002   208.870002   212.960007   212.960007
# 75%     266.450012   270.927513   262.102501   266.774994   266.774994
# max     673.690002   786.140015   673.520020   780.000000   780.000000
#
#              Volume
# count  2.416000e+03
# mean   5.572722e+06
# std    4.987809e+06
# min    1.185000e+05
# 25%    1.899275e+06
# 50%    4.578400e+06
# 75%    7.361150e+06
# max    4.706500e+07

# %%
tesla_df.tail()
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 2411  2020-01-28  568.489990  576.809998  558.080017  566.900024  566.900024
# 2412  2020-01-29  575.690002  589.799988  567.429993  580.989990  580.989990
# 2413  2020-01-30  632.419983  650.880005  618.000000  640.809998  640.809998
# 2414  2020-01-31  640.000000  653.000000  632.520020  650.570007  650.570007
# 2415  2020-02-03  673.690002  786.140015  673.520020  780.000000  780.000000
#
#         Volume
# 2411  11788500
# 2412  17801500
# 2413  29005700
# 2414  15719300
# 2415  47065000

# %%
tesla_df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
tesla_df.index()
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2010-06-29   19.000000   25.000000   17.540001   23.889999   23.889999
# 1     2010-06-30   25.790001   30.420000   23.299999   23.830000   23.830000
# 2     2010-07-01   25.000000   25.920000   20.270000   21.959999   21.959999
# 3     2010-07-02   23.000000   23.100000   18.709999   19.200001   19.200001
# 4     2010-07-06   20.000000   20.000000   15.830000   16.110001   16.110001
# ...          ...         ...         ...         ...         ...         ...
# 2411  2020-01-28  568.489990  576.809998  558.080017  566.900024  566.900024
# 2412  2020-01-29  575.690002  589.799988  567.429993  580.989990  580.989990
# 2413  2020-01-30  632.419983  650.880005  618.000000  640.809998  640.809998
# 2414  2020-01-31  640.000000  653.000000  632.520020  650.570007  650.570007
# 2415  2020-02-03  673.690002  786.140015  673.520020  780.000000  780.000000
#
#         Volume
# 0     18766300
# ...

# %%
tesla_df.set_index('Date', inplace=True)
tesla_df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-06-29   19.000000   25.000000   17.540001   23.889999   23.889999
# 2010-06-30   25.790001   30.420000   23.299999   23.830000   23.830000
# 2010-07-01   25.000000   25.920000   20.270000   21.959999   21.959999
# 2010-07-02   23.000000   23.100000   18.709999   19.200001   19.200001
# 2010-07-06   20.000000   20.000000   15.830000   16.110001   16.110001
# ...                ...         ...         ...         ...         ...
# 2020-01-28  568.489990  576.809998  558.080017  566.900024  566.900024
# 2020-01-29  575.690002  589.799988  567.429993  580.989990  580.989990
# 2020-01-30  632.419983  650.880005  618.000000  640.809998  640.809998
# 2020-01-31  640.000000  653.000000  632.520020  650.570007  650.570007
# 2020-02-03  673.690002  786.140015  673.520020  780.000000  780.000000
#
#               Volume
# Date
# 2010-06-29  18766300
# 2010-06-30  17187100
# 2010-07-01   8218800
# ...

# %%
tesla_df.iplot()
# Out:
# <div>
#
#
#             <div id="b09929f0-06ca-40d2-8b55-39d189d9a2fe" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("b09929f0-06ca-40d2-8b55-39d189d9a2fe")) {
#                     Plotly.newPlot(
#                         'b09929f0-06ca-40d2-8b55-39d189d9a2fe',
# ...

# %%
tesla_df['Volume'].sort_values(ascending = True).unique()
plt.figure(figsize=(20,9))
plt.plot(tesla_df['Volume'].sort_values(ascending = True).unique())
plt.title('Line Plot', fontsize = 20)
plt.xlabel('Row Indexes', fontsize = 20)
plt.ylabel('Volume',fontsize = 20)
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
plt.figure(figsize=(12,8))
sns.set_style('darkgrid')
plt.scatter(x = tesla_df.index, y = tesla_df['Volume'])
